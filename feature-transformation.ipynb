# %%
import pandas as pd

# Reading the CSV file
df = pd.read_csv('C:/Users/anubh/OneDrive/Desktop/diabetes.csv')

# Display the first 5 rows of the dataframe
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Z-Score Normalization
parameters = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

for param in parameters:
    mean = df[param].mean()
    df[param] = df[param] - mean
    max_value = df[param].max()
    df[param] = df[param] / max_value

df
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.163813  0.347037       0.054723       0.184335 -0.104150  0.045786
# 1      -0.216272 -0.459565      -0.058711       0.107866 -0.104150 -0.153602
# 2       0.315847  0.795149      -0.096522      -0.261732 -0.104150 -0.247599
# 3      -0.216272 -0.408352      -0.058711       0.031397  0.018534 -0.110876
# 4      -0.292289  0.206202      -0.550255       0.184335  0.115114  0.316384
# ..           ...       ...            ...            ...       ...       ...
# 763     0.467881 -0.254714       0.130345       0.350017  0.130776  0.025847
# 764    -0.140255  0.014154       0.016912       0.082376 -0.104150  0.136935
# 765     0.087796  0.001350       0.054723       0.031397  0.042026 -0.164996
# 766    -0.216272  0.065366      -0.172144      -0.261732 -0.104150 -0.053908
# 767    -0.216272 -0.357139       0.016912       0.133355 -0.104150 -0.045363
#
# ...

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure and a set of subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# List of columns to plot
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# Plot each column
for i, column in enumerate(columns):
    sns.histplot(df[column], kde=True, ax=axes[i//3, i%3])
    axes[i//3, i%3].set_title(f'Distribution of {column}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Loop through each parameter and plot the distribution for Outcome = 1
for param in parameters:
    feature_outcome_1 = df[df['Outcome'] == 1][[param, 'Outcome']]
    
    plt.figure(figsize=(10, 6))
    plt.hist(feature_outcome_1[param], bins=20, edgecolor='k', alpha=0.7)
    plt.title(f'{param} Distribution for Outcome = 1')
    plt.xlabel(param)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
