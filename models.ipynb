# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 20.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 6.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 16.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 17.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
import pandas as pd
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
from pycaret.classification import *
s = setup(data=df, target='Outcome')
# Out:
# <style type="text/css">
# #T_c3355_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c3355">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3355_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c3355_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3355_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3355_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c3355_row0_col1" class="data row0 col1" >8861</td>
#     </tr>
#     <tr>
#       <th id="T_c3355_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3355_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c3355_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_c3355_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
diff_models= compare_models()
# Out:
# <style type="text/css">
# #T_1edbb th {
#   text-align: left;
# }
# ...

# %%
from pycaret.classification import *

setup(data=df, target='Outcome', train_size = 0.7, verbose=False)
print("Comparing all Machine Learning Algos with Different Parameters")
cm = compare_models()
# Out:
# Comparing all Machine Learning Algos with Different Parameters
# <style type="text/css">
# #T_82b09 th {
#   text-align: left;
# }
# ...

# %%
#We use Gradient Boosting Classifier as it has the highest accurcay
gbcModel = create_model('gbc')
# Out:
# <style type="text/css">
# #T_3da47_row10_col0, #T_3da47_row10_col1, #T_3da47_row10_col2, #T_3da47_row10_col3, #T_3da47_row10_col4, #T_3da47_row10_col5, #T_3da47_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3da47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3da47_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3da47_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3da47_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3da47_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3da47_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3da47_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3da47_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(gbcModel, plot='confusion_matrix')

# %%
plot_model(gbcModel, plot='learning')
